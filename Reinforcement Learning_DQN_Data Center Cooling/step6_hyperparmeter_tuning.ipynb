# %%
#from google.colab import drive
#drive.mount('/gdrive')
#%cd /gdrive

# This will prompt for authorization.
#drive.mount('/content/drive')

# %%
# Testing the AI
# Installing Keras
# conda install -c conda-forge keras

# Importing the libraries and the other python files
import os
import numpy as np
import random as rn
from keras.models import load_model 
import step1_env as environment
import pandas as pd
import step2_buildingbrain as brain
import step3_dqn_rl_algo as dqn
import pandas as pd

# %%
# set a seed value
seed_value = 314159

# %%
# Set random seeds to the same value 
# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)
# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)
# 4. Set `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# 5. Configure a new global `tensorflow` session
from keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
# Comment out if you are not using a local GPU
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Comment out if you are not using a local GPU
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
## Create a list of hyper parameter values to be tested
h_epsilon = [0.1,0.3,0.6,0.9]
h_learning_rate = [0.000005,0.00001,0.00005]
h_early_stopping = [True,False]
h_epoch = [50,100,150]

# %%
#Create list of hyper parmeter values to try that will cover all combinations
grid_search = []
for e in h_epsilon:
    for lr in h_learning_rate:
        for es in h_early_stopping:
            for ep in h_epoch:
                grid_search.append({'epsilon':e,'learning_rate':lr,'number_epochs':ep,'early_stopping':es})

# %%
results = []

# %%
# Define the timesteps for each episode 2 days was used for hyper parameter tuning.
time_steps = 60*24*2
for parameter in grid_search:
	# Training the AI
	# Installing Keras
	# conda install -c conda-forge keras

	# Importing the libraries and the other python files


	# Setting seeds for reproducibility 

	os.environ['PYTHONHASHSEED'] = '0'
	np.random.seed(42)
	rn.seed(12345)


	# SETTING THE PARAMETERS
	run = 'model' ## name for the run. Used to save the model file.
	epsilon = parameter['epsilon']
	learning_rate = parameter['learning_rate']
	number_actions = 5
	direction_boundary = (number_actions - 1) / 2
	number_epochs = parameter['number_epochs']
	max_memory = 3000 
	batch_size = 512 
	temperature_step = 1.5
	early_stopping = parameter['early_stopping']

	# Creating a string that will be used to store the output of each run. 
	run = 'e_'+ str(epsilon) +'_lr_' + str(learning_rate) + '_ep_' + str(number_epochs) + '_es_' + str(early_stopping)

	# BUILDING THE ENVIRONMENT BY SIMPLY CREATING AN OBJECT OF THE ENVIRONMENT CLASS
	env = environment.Environment(optimal_temperature = (18.0, 24.0),
								initial_month = 0,
								initial_number_users = 20,
								initial_rate_data = 30)

	# BUILDING THE BRAIN BY SIMPLY CREATING AN OBJECT OF THE BRAIN CLASS
	import step2_buildingbrain as brain
	brain = brain.Brain(learning_rate = learning_rate, number_actions = number_actions)


	# BUILDING THE DQN MODEL BY SIMPLY CREATING AN OBJECT OF THE DQN CLASS
	import step3_dqn_rl_algo as dqn
	dqn = dqn.DQN(max_memory = max_memory, discount = 0.9)

	# CHOOSING THE MODE
	train = True

	# TRAINING THE AI
	env.train = train
	model = brain.model

	patience = 10
	best_total_reward = -np.inf
	patience_count = 0


	if (env.train):
		# STARTING THE LOOP OVER ALL THE EPOCHS (1 Epoch = 5 Months)
		for epoch in range(1, number_epochs):
			# INITIALIAZING ALL THE VARIABLES OF BOTH THE ENVIRONMENT AND THE TRAINING LOOP
			total_reward = 0
			loss = 0.
			new_month = np.random.randint(0, 12)
			env.reset(new_month = new_month)
			game_over = False
			current_state, _, _ = env.observe()
			timestep = 0

			# STARTING THE LOOP OVER ALL THE TIMESTEPS (1 Timestep = 1 Minute) IN ONE EPOCH
			while ((not game_over) and timestep <= time_steps):

				# PLAYING THE NEXT ACTION BY EXPLORATION
				if np.random.rand() <= epsilon:
					action = np.random.randint(0, number_actions)
					if (action - direction_boundary < 0): 
						direction = -1
					else:
						direction = 1
					energy_ai = abs(action - direction_boundary) * temperature_step 


				# PLAYING THE NEXT ACTION BY INFERENCE

				else:
					q_values = model.predict(current_state) 
					action = np.argmax(q_values[0])
					if (action - direction_boundary < 0): 
						direction = -1
					else:
						direction = 1
					energy_ai = abs(action - direction_boundary) * temperature_step 


				# UPDATING THE ENVIRONMENT AND REACHING THE NEXT STATE
				next_state, reward, game_over = env.update_env(direction, energy_ai, int(timestep / (30*24*60)))


				total_reward += reward
				# STORING THIS NEW TRANSITION INTO THE MEMORY

				dqn.remember([current_state, action, reward, next_state], game_over)



				# GATHERING IN TWO SEPARATE BATCHES THE INPUTS AND THE TARGETS

				inputs, targets = dqn.get_batch(model, batch_size = batch_size)

				# COMPUTING THE LOSS OVER THE TWO WHOLE BATCHES OF INPUTS AND TARGETS
				loss += model.train_on_batch(inputs, targets)
				timestep += 1
				current_state = next_state


			# PRINTING THE TRAINING RESULTS FOR EACH EPOCH
			#print("\n")
			print(run)
			print("Epoch: {:03d}/{:03d}".format(epoch, number_epochs))
			print("Total Energy spent with an AI: {:.0f}".format(env.total_energy_ai))
			print("Total Energy spent with no AI: {:.0f}".format(env.total_energy_noai)) 

			# EARLY STOPPING
			if (early_stopping):
				if (total_reward <= best_total_reward):
					patience_count += 1
				elif (total_reward > best_total_reward):
					best_total_reward = total_reward
					patience_count = 0
			
			if (patience_count >= patience):
				print("Early Stopping")
				break
	## TESTING THE MODEL
	
	# Setting seeds for reproducibility
	os.environ['PYTHONHASHSEED'] = '0' 
	
	# Note from BREMNER: Should be different random seeds from above in 
	# order to test a different random draw during testing
	
	np.random.seed(42)
	rn.seed(12345)
	
	# SETTING THE PARAMETERS
	number_actions = 5
	direction_boundary = (number_actions - 1) / 2
	temperature_step = 1.5

	# BUILDING THE ENVIRONMENT BY SIMPLY CREATING AN OBJECT OF THE ENVIRONMENT CLASS
	env = environment.Environment(optimal_temperature = (18.0, 24.0), initial_month = 0,
									initial_number_users = 20, initial_rate_data = 30)

	# CHOOSING THE MODE
	train = False
	env.train = train
	current_state, _, _ = env.observe()
	run_results = []
	for timestep in range(0, time_steps):
		q_values = model.predict(current_state)
		action = np.argmax(q_values[0])
		
		if (action - direction_boundary < 0): 
			direction = -1
		else:
			direction = 1

		energy_ai = abs(action - direction_boundary) * temperature_step 
		next_state, reward, game_over = env.update_env(direction, \
														energy_ai, \
														int(timestep / (30*24*60)))

		current_state = next_state
		print("\n")
		print(timestep)
		print("Total Energy spent with an AI: {:.0f}".format(env.total_energy_ai)) 
		print("Total Energy spent with no AI: {:.0f}".format(env.total_energy_noai))
		print("ENERGY SAVED: {:.0f} %".format(100*(env.total_energy_noai - env.total_energy_ai)
											/ env.total_energy_noai))
		# Save the results to a list that will then be passed to a dataframe.
		run_results.append({
			'timestep':timestep,
			'total_energy_ai':env.total_energy_ai,
			'total_energy_noai':env.total_energy_noai,
			'% Savings': (env.total_energy_noai - env.total_energy_ai)/env.total_energy_noai,
			'intrinsic_temp' : env.intrinsic_temperature,
			'temperature_ai' : env.temperature_ai,
			'temperature_noai': env.temperature_noai,
			'direction' : direction,
			'energy_ai' : energy_ai})
	results.append(run_results[-1]['% Savings'])
	# Save the results and the model file for the run
	df = pd.DataFrame(run_results)
	df.to_csv(run +".csv")
	model.save(run+".h5")
	print("\n")
	print(run)
	print('Savings: ' + str(run_results[-1]['% Savings']))
# Out:
# t with no AI: 12724
# ENERGY SAVED: 48 %
#
#
# 2679
# Total Energy spent with an AI: 6608
# Total Energy spent with no AI: 12726
# ENERGY SAVED: 48 %
#
#
# 2680
# Total Energy spent with an AI: 6609
# Total Energy spent with no AI: 12732
# ENERGY SAVED: 48 %
#
#
# 2681
# Total Energy spent with an AI: 6611
# Total Energy spent with no AI: 12733
# ENERGY SAVED: 48 %
#
#
# 2682
# Total Energy spent with an AI: 6612
# Total Energy spent with no AI: 12734
# ENERGY SAVED: 48 %
#
#
# 2683
# Total Energy spent with an AI: 6614
# Total Energy spent with no AI: 12736
# ENERGY SAVED: 48 %
#
#
# 2684
# Total Energy spent with an AI: 6615
# Total Energy spent with no AI: 12740
# ENERGY SAVED: 48 %
#
#
# 2685
# Total Energy spent with an AI: 6617
# Total Energy spent with no AI: 12740
# ENERGY SAVED: 48 %
#
#
# 2686
# Total Energy spent with an AI: 6618
# Total Energy spent with no AI: 12741
# ENERGY SAVED: 48 %
#
#
# 2687
# Total Energy spent with an AI: 6621
# Total Energy spent with no AI: 12746
# ENERGY SAVED: 48 %
#
#
# 2688
# Total Energy spent with an AI: 6623
# Total Energy spent with no AI: 12758
# ENERGY SAVED: 48 %
#
#
# 2689
# Total Energy spent with an AI: 6624
# Total Energy spent with no AI: 12758
# ENERGY SAVED: 48 %
#
#
# 2690
# Total Energy spent with an AI: 6626
# Total Energy spent with no AI: 12759
# ENERGY SAVED: 48 %
#
#
# 2691
# Total Energy spent with an AI: 6627
# Total Energy spent with no AI: 12760
# ENERGY SAVED: 48 %
#
#
# 2692
# Total Energy spent with an AI: 6629
# Total Energy spent with no AI: 12760
# ENERGY SAVED: 48 %
#
#
# 2693
# Total Energy spent with an AI: 6632
# Total Energy spent with no AI: 12763
# ENERGY SAVED: 48 %
#
#
# 2694
# Total Energy spent with an AI: 6633
# Total Energy spent with no AI: 12766
# ENERGY SAVED: 48 %
#
#
# 2695
# Total Energy spent with an AI: 6636
# Total Energy spent with no AI: 12773
# ENERGY SAVED: 48 %
#
#
# 2696
# Total Energy spent with an AI: 6638
# Total Energy spent with no AI: 12779
# ENERGY SAVED: 48 %
#
#
# 2697
# Total Energy spent with an AI: 6639
# Total Energy spent with no AI: 12781
# ENERGY SAVED: 48 %
#
#
# 2698
# Total Energy spent with an AI: 6641
# Total Energy spent with no AI: 12781
# ENERGY SAVED: 48 %
#
#
# 2699
# Total Energy spent with an AI: 6642
# Total Energy spent with no AI: 12790
# ENERGY SAVED: 48 %
#
#
# 2700
# Total Energy spent with an AI: 6644
# Total Energy spent with no AI: 12798
# ENERGY SAVED: 48 %
#
#
# 2701
# Total Energy spent with an AI: 6645
# Total Energy spent with no AI: 12802
# ENERGY SAVED: 48 %
#
#
# 2702
# Total Energy spent with an AI: 6648
# Total Energy spent with no AI: 12807
# ENERGY SAVED: 48 %
#
#
# 2703
# Total Energy spent with an AI: 6651
# Total Energy spent with no AI: 12809
# ENERGY SAVED: 48 %
#
#
# 2704
# Total Energy spent with an AI: 6653
# Total Energy spent with no AI: 12810
# ENERGY SAVED: 48 %
#
#
# 2705
# Total Energy spent with an AI: 6654
# Total Energy spent with no AI: 12816
# ENERGY SAVED: 48 %
#
#
# 2706
# Total Energy spent with an AI: 6656
# Total Energy spent with no AI: 12816
# ENERGY SAVED: 48 %
#
#
# 2707
# Total Energy spent with an AI: 6659
# Total Energy spent with no AI: 12826
# ENERGY SAVED: 48 %
#
#
# 2708
# Total Energy spent with an AI: 6662
# Total Energy spent with no AI: 12829
# ENERGY SAVED: 48 %
#
#
# 2709
# Total Energy spent with an AI: 6663
# Total Energy spent with no AI: 12836
# ENERGY SAVED: 48 %
#
#
# 2710
# Total Energy spent with an AI: 6665
# Total Energy spent with no AI: 12840
# ENERGY SAVED: 48 %
#
#
# 2711
# Total Energy spent with an AI: 6726
# Total Energy spent with no AI: 12844
# ENERGY SAVED: 48 %
#
#
# 2712
# Total Energy spent with an AI: 6729
# Total Energy spent with no AI: 12846
# ENERGY SAVED: 48 %
#
#
# 2713
# Total Energy spent with an AI: 6732
# Total Energy spent with no AI: 12850
# ENERGY SAVED: 48 %
#
#
# 2714
# Total Energy spent with an AI: 6735
# Total Energy spent with no AI: 12852
# ENERGY SAVED: 48 %
#
#
# 2715
# Total Energy spent with an AI: 6738
# Total Energy spent with no AI: 12853
# ENERGY SAVED: 48 %
#
#
# 2716
# Total Energy spent with an AI: 6741
# Total Energy spent with no AI: 12859
# ENERGY SAVED: 48 %
#
#
# 2717
# Total Energy spent with an AI: 6744
# Total Energy spent with no AI: 12860
# ENERGY SAVED: 48 %
#
#
# 2718
# Total Energy spent with an AI: 6747
# Total Energy spent with no AI: 12865
# ENERGY SAVED: 48 %
#
#
# 2719
# Total Energy spent with an AI: 6749
# Total Energy spent with no AI: 12870
# ENERGY SAVED: 48 %
#
#
# 2720
# Total Energy spent with an AI: 6752
# Total Energy spent with no AI: 12878
# ENERGY SAVED: 48 %
#
#
# 2721
# Total Energy spent with an AI: 6753
# Total Energy spent with no AI: 12883
# ENERGY SAVED: 48 %
#
#
# 2722
# Total Energy spent with an AI: 6756
# Total Energy spent with no AI: 12896
# ENERGY SAVED: 48 %
#
#
# 2723
# Total Energy spent with an AI: 6759
# Total Energy spent with no AI: 12901
# ENERGY SAVED: 48 %
#
#
# 2724
# Total Energy spent with an AI: 6761
# Total Energy spent with no AI: 12908
# ENERGY SAVED: 48 %
#
#
# 2725
# Total Energy spent with an AI: 6762
# Total Energy spent with no AI: 12909
# ENERGY SAVED: 48 %
#
#
# 2726
# Total Energy spent with an AI: 6765
# Total Energy spent with no AI: 12914
# ENERGY SAVED: 48 %
#
#
# 2727
# Total Energy spent with an AI: 6767
# Total Energy spent with no AI: 12923
# ENERGY SAVED: 48 %
#
#
# 2728
# Total Energy spent with an AI: 6768
# Total Energy spent with no AI: 12923
# ENERGY SAVED: 48 %
#
#
# 2729
# Total Energy spent with an AI: 6770
# Total Energy spent with no AI: 12924
# ENERGY SAVED: 48 %
#
#
# 2730
# Total Energy spent with an AI: 6771
# Total Energy spent with no AI: 12926
# ENERGY SAVED: 48 %
#
#
# 2731
# Total Energy spent with an AI: 6774
# Total Energy spent with no AI: 12930
# ENERGY SAVED: 48 %
#
#
# 2732
# Total Energy spent with an AI: 6777
# Total Energy spent with no AI: 12934
# ENERGY SAVED: 48 %
#
#
# 2733
# Total Energy spent with an AI: 6779
# Total Energy spent with no AI: 12940
# ENERGY SAVED: 48 %
#
#
# 2734
# Total Energy spent with an AI: 6780
# Total Energy spent with no AI: 12940
# ENERGY SAVED: 48 %
#
#
# 2735
# Total Energy spent with an AI: 6783
# Total Energy spent with no AI: 12947
# ENERGY SAVED: 48 %
#
#
# 2736
# Total Energy spent with an AI: 6785
# Total Energy spent with no AI: 12958
# ENERGY SAVED: 48 %
#
#
# 2737
# Total Energy spent with an AI: 6849
# Total Energy spent with no AI: 12959
# ENERGY SAVED: 47 %
#
#
# 2738
# Total Energy spent with an AI: 6852
# Total Energy spent with no AI: 12969
# ENERGY SAVED: 47 %
#
#
# 2739
# Total Energy spent with an AI: 6855
# Total Energy spent with no AI: 12969
# ENERGY SAVED: 47 %
#
#
# 2740
# Total Energy spent with an AI: 6858
# Total Energy spent with no AI: 12970
# ENERGY SAVED: 47 %
#
#
# 2741
# Total Energy spent with an AI: 6861
# Total Energy spent with no AI: 12970
# ENERGY SAVED: 47 %
#
#
# 2742
# Total Energy spent with an AI: 6864
# Total Energy spent with no AI: 12972
# ENERGY SAVED: 47 %
#
#
# 2743
# Total Energy spent with an AI: 6867
# Total Energy spent with no AI: 12972
# ENERGY SAVED: 47 %
#
#
# 2744
# Total Energy spent with an AI: 6868
# Total Energy spent with no AI: 12981
# ENERGY SAVED: 47 %
#
#
# 2745
# Total Energy spent with an AI: 6870
# Total Energy spent with no AI: 12981
# ENERGY SAVED: 47 %
#
#
# 2746
# Total Energy spent with an AI: 6872
# Total Energy spent with no AI: 12985
# ENERGY SAVED: 47 %
#
#
# 2747
# Total Energy spent with an AI: 6873
# Total Energy spent with no AI: 12985
# ENERGY SAVED: 47 %
#
#
# 2748
# Total Energy spent with an AI: 6876
# Total Energy spent with no AI: 12998
# ENERGY SAVED: 47 %
#
#
# 2749
# Total Energy spent with an AI: 6879
# Total Energy spent with no AI: 13007
# ENERGY SAVED: 47 %
#
#
# 2750
# Total Energy spent with an AI: 6882
# Total Energy spent with no AI: 13017
# ENERGY SAVED: 47 %
#
#
# 2751
# Total Energy spent with an AI: 6885
# Total Energy spent with no AI: 13017
# ENERGY SAVED: 47 %
#
#
# 2752
# Total Energy spent with an AI: 6888
# Total Energy spent with no AI: 13020
# ENERGY SAVED: 47 %
#
#
# 2753
# Total Energy spent with an AI: 6890
# Total Energy spent with no AI: 13026
# ENERGY SAVED: 47 %
#
#
# 2754
# Total Energy spent with an AI: 6951
# Total Energy spent with no AI: 13026
# ENERGY SAVED: 47 %
#
#
# 2755
# Total Energy spent with an AI: 6954
# Total Energy spent with no AI: 13033
# ENERGY SAVED: 47 %
#
#
# 2756
# Total Energy spent with an AI: 6957
# Total Energy spent with no AI: 13034
# ENERGY SAVED: 47 %
#
#
# 2757
# Total Energy spent with an AI: 6960
# Total Energy spent with no AI: 13046
# ENERGY SAVED: 47 %
#
#
# 2758
# Total Energy spent with an AI: 6963
# Total Energy spent with no AI: 13058
# ENERGY SAVED: 47 %
#
#
# 2759
# Total Energy spent with an AI: 6966
# Total Energy spent with no AI: 13065
# ENERGY SAVED: 47 %
#
#
# 2760
# Total Energy spent with an AI: 6969
# Total Energy spent with no AI: 13066
# ENERGY SAVED: 47 %
#
#
# 2761
# Total Energy spent with an AI: 6972
# Total Energy spent with no AI: 13069
# ENERGY SAVED: 47 %
#
#
# 2762
# Total Energy spent with an AI: 6975
# Total Energy spent with no AI: 13080
# ENERGY SAVED: 47 %
#
#
# 2763
# Total Energy spent with an AI: 6978
# Total Energy spent with no AI: 13089
# ENERGY SAVED: 47 %
#
#
# 2764
# Total Energy spent with an AI: 6981
# Total Energy spent with no AI: 13090
# ENERGY SAVED: 47 %
#
#
# 2765
# Total Energy spent with an AI: 6984
# Total Energy spent with no AI: 13090
# ENERGY SAVED: 47 %
#
#
# 2766
# Total Energy spent with an AI: 6987
# Total Energy spent with no AI: 13090
# ENERGY SAVED: 47 %
#
#
# 2767
# Total Energy spent with an AI: 6990
# Total Energy spent with no AI: 13101
# ENERGY SAVED: 47 %
#
#
# 2768
# Total Energy spent with an AI: 6993
# Total Energy spent with no AI: 13109
# ENERGY SAVED: 47 %
#
#
# 2769
# Total Energy spent with an AI: 6996
# Total Energy spent with no AI: 13112
# ENERGY SAVED: 47 %
#
#
# 2770
# Total Energy spent with an AI: 6999
# Total Energy spent with no AI: 13117
# ENERGY SAVED: 47 %
#
#
# 2771
# Total Energy spent with an AI: 7002
# Total Energy spent with no AI: 13129
# ENERGY SAVED: 47 %
#
#
# 2772
# Total Energy spent with an AI: 7005
# Total Energy spent with no AI: 13131
# ENERGY SAVED: 47 %
#
#
# 2773
# Total Energy spent with an AI: 7008
# Total Energy spent with no AI: 13141
# ENERGY SAVED: 47 %
#
#
# 2774
# Total Energy spent with an AI: 7011
# Total Energy spent with no AI: 13154
# ENERGY SAVED: 47 %
#
#
# 2775
# Total Energy spent with an AI: 7014
# Total Energy spent with no AI: 13159
# ENERGY SAVED: 47 %
#
#
# 2776
# Total Energy spent with an AI: 7017
# Total Energy spent with no AI: 13166
# ENERGY SAVED: 47 %
#
#
# 2777
# Total Energy spent with an AI: 7082
# Total Energy spent with no AI: 13167
# ENERGY SAVED: 46 %
#
#
# 2778
# Total Energy spent with an AI: 7085
# Total Energy spent with no AI: 13167
# ENERGY SAVED: 46 %
#
#
# 2779
# Total Energy spent with an AI: 7088
# Total Energy spent with no AI: 13167
# ENERGY SAVED: 46 %
#
#
# 2780
# Total Energy spent with an AI: 7091
# Total Energy spent with no AI: 13168
# ENERGY SAVED: 46 %
#
#
# 2781
# Total Energy spent with an AI: 7094
# Total Energy spent with no AI: 13177
# ENERGY SAVED: 46 %
#
#
# 2782
# Total Energy spent with an AI: 7097
# Total Energy spent with no AI: 13191
# ENERGY SAVED: 46 %
#
#
# 2783
# Total Energy spent with an AI: 7100
# Total Energy spent with no AI: 13198
# ENERGY SAVED: 46 %
#
#
# 2784
# Total Energy spent with an AI: 7103
# Total Energy spent with no AI: 13203
# ENERGY SAVED: 46 %
#
#
# 2785
# Total Energy spent with an AI: 7106
# Total Energy spent with no AI: 13203
# ENERGY SAVED: 46 %
#
#
# 2786
# Total Energy spent with an AI: 7109
# Total Energy spent with no AI: 13206
# ENERGY SAVED: 46 %
#
#
# 2787
# Total Energy spent with an AI: 7112
# Total Energy spent with no AI: 13206
# ENERGY SAVED: 46 %
#
#
# 2788
# Total Energy spent with an AI: 7115
# Total Energy spent with no AI: 13214
# ENERGY SAVED: 46 %
#
#
# 2789
# Total Energy spent with an AI: 7175
# Total Energy spent with no AI: 13218
# ENERGY SAVED: 46 %
#
#
# 2790
# Total Energy spent with an AI: 7178
# Total Energy spent with no AI: 13218
# ENERGY SAVED: 46 %
#
#
# 2791
# Total Energy spent with an AI: 7181
# Total Energy spent with no AI: 13218
# ENERGY SAVED: 46 %
#
#
# 2792
# Total Energy spent with an AI: 7184
# Total Energy spent with no AI: 13224
# ENERGY SAVED: 46 %
#
#
# 2793
# Total Energy spent with an AI: 7187
# Total Energy spent with no AI: 13230
# ENERGY SAVED: 46 %
#
#
# 2794
# Total Energy spent with an AI: 7190
# Total Energy spent with no AI: 13230
# ENERGY SAVED: 46 %
#
#
# 2795
# Total Energy spent with an AI: 7193
# Total Energy spent with no AI: 13230
# ENERGY SAVED: 46 %
#
#
# 2796
# Total Energy spent with an AI: 7196
# Total Energy spent with no AI: 13235
# ENERGY SAVED: 46 %
#
#
# 2797
# Total Energy spent with an AI: 7199
# Total Energy spent with no AI: 13242
# ENERGY SAVED: 46 %
#
#
# 2798
# Total Energy spent with an AI: 7202
# Total Energy spent with no AI: 13256
# ENERGY SAVED: 46 %
#
#
# 2799
# Total Energy spent with an AI: 7205
# Total Energy spent with no AI: 13266
# ENERGY SAVED: 46 %
#
#
# 2800
# Total Energy spent with an AI: 7208
# Total Energy spent with no AI: 13267
# ENERGY SAVED: 46 %
#
#
# 2801
# Total Energy spent with an AI: 7211
# Total Energy spent with no AI: 13268
# ENERGY SAVED: 46 %
#
#
# 2802
# Total Energy spent with an AI: 7214
# Total Energy spent with no AI: 13272
# ENERGY SAVED: 46 %
#
#
# 2803
# Total Energy spent with an AI: 7217
# Total Energy spent with no AI: 13282
# ENERGY SAVED: 46 %
#
#
# 2804
# Total Energy spent with an AI: 7220
# Total Energy spent with no AI: 13290
# ENERGY SAVED: 46 %
#
#
# 2805
# Total Energy spent with an AI: 7223
# Total Energy spent with no AI: 13290
# ENERGY SAVED: 46 %
#
#
# 2806
# Total Energy spent with an AI: 7226
# Total Energy spent with no AI: 13292
# ENERGY SAVED: 46 %
#
#
# 2807
# Total Energy spent with an AI: 7229
# Total Energy spent with no AI: 13300
# ENERGY SAVED: 46 %
#
#
# 2808
# Total Energy spent with an AI: 7232
# Total Energy spent with no AI: 13306
# ENERGY SAVED: 46 %
#
#
# 2809
# Total Energy spent with an AI: 7295
# Total Energy spent with no AI: 13306
# ENERGY SAVED: 45 %
#
#
# 2810
# Total Energy spent with an AI: 7298
# Total Energy spent with no AI: 13307
# ENERGY SAVED: 45 %
#
#
# 2811
# Total Energy spent with an AI: 7301
# Total Energy spent with no AI: 13316
# ENERGY SAVED: 45 %
#
#
# 2812
# Total Energy spent with an AI: 7304
# Total Energy spent with no AI: 13318
# ENERGY SAVED: 45 %
#
#
# 2813
# Total Energy spent with an AI: 7307
# Total Energy spent with no AI: 13326
# ENERGY SAVED: 45 %
#
#
# 2814
# Total Energy spent with an AI: 7310
# Total Energy spent with no AI: 13328
# ENERGY SAVED: 45 %
#
#
# 2815
# Total Energy spent with an AI: 7378
# Total Energy spent with no AI: 13333
# ENERGY SAVED: 45 %
#
#
# 2816
# Total Energy spent with an AI: 7382
# Total Energy spent with no AI: 13347
# ENERGY SAVED: 45 %
#
#
# 2817
# Total Energy spent with an AI: 7384
# Total Energy spent with no AI: 13372
# ENERGY SAVED: 45 %
#
#
# 2818
# Total Energy spent with an AI: 7388
# Total Energy spent with no AI: 13403
# ENERGY SAVED: 45 %
#
#
# 2819
# Total Energy spent with an AI: 7390
# Total Energy spent with no AI: 13430
# ENERGY SAVED: 45 %
#
#
# 2820
# Total Energy spent with an AI: 7394
# Total Energy spent with no AI: 13446
# ENERGY SAVED: 45 %
#
#
# 2821
# Total Energy spent with an AI: 7396
# Total Energy spent with no AI: 13446
# ENERGY SAVED: 45 %
#
#
# 2822
# Total Energy spent with an AI: 7400
# Total Energy spent with no AI: 13446
# ENERGY SAVED: 45 %
#
#
# 2823
# Total Energy spent with an AI: 7402
# Total Energy spent with no AI: 13457
# ENERGY SAVED: 45 %
#
#
# 2824
# Total Energy spent with an AI: 7406
# Total Energy spent with no AI: 13457
# ENERGY SAVED: 45 %
#
#
# 2825
# Total Energy spent with an AI: 7408
# Total Energy spent with no AI: 13460
# ENERGY SAVED: 45 %
#
#
# 2826
# Total Energy spent with an AI: 7471
# Total Energy spent with no AI: 13464
# ENERGY SAVED: 45 %
#
#
# 2827
# Total Energy spent with an AI: 7474
# Total Energy spent with no AI: 13469
# ENERGY SAVED: 45 %
#
#
# 2828
# Total Energy spent with an AI: 7477
# Total Energy spent with no AI: 13472
# ENERGY SAVED: 45 %
#
#
# 2829
# Total Energy spent with an AI: 7480
# Total Energy spent with no AI: 13472
# ENERGY SAVED: 44 %
#
#
# 2830
# Total Energy spent with an AI: 7483
# Total Energy spent with no AI: 13477
# ENERGY SAVED: 44 %
#
#
# 2831
# Total Energy spent with an AI: 7486
# Total Energy spent with no AI: 13484
# ENERGY SAVED: 44 %
#
#
# 2832
# Total Energy spent with an AI: 7489
# Total Energy spent with no AI: 13488
# ENERGY SAVED: 44 %
#
#
# 2833
# Total Energy spent with an AI: 7492
# Total Energy spent with no AI: 13488
# ENERGY SAVED: 44 %
#
#
# 2834
# Total Energy spent with an AI: 7495
# Total Energy spent with no AI: 13488
# ENERGY SAVED: 44 %
#
#
# 2835
# Total Energy spent with an AI: 7498
# Total Energy spent with no AI: 13488
# ENERGY SAVED: 44 %
#
#
# 2836
# Total Energy spent with an AI: 7501
# Total Energy spent with no AI: 13488
# ENERGY SAVED: 44 %
#
#
# 2837
# Total Energy spent with an AI: 7504
# Total Energy spent with no AI: 13490
# ENERGY SAVED: 44 %
#
#
# 2838
# Total Energy spent with an AI: 7507
# Total Energy spent with no AI: 13490
# ENERGY SAVED: 44 %
#
#
# 2839
# Total Energy spent with an AI: 7510
# Total Energy spent with no AI: 13496
# ENERGY SAVED: 44 %
#
#
# 2840
# Total Energy spent with an AI: 7513
# Total Energy spent with no AI: 13503
# ENERGY SAVED: 44 %
#
#
# 2841
# Total Energy spent with an AI: 7516
# Total Energy spent with no AI: 13504
# ENERGY SAVED: 44 %
#
#
# 2842
# Total Energy spent with an AI: 7519
# Total Energy spent with no AI: 13506
# ENERGY SAVED: 44 %
#
#
# 2843
# Total Energy spent with an AI: 7522
# Total Energy spent with no AI: 13506
# ENERGY SAVED: 44 %
#
#
# 2844
# Total Energy spent with an AI: 7525
# Total Energy spent with no AI: 13512
# ENERGY SAVED: 44 %
#
#
# 2845
# Total Energy spent with an AI: 7528
# Total Energy spent with no AI: 13516
# ENERGY SAVED: 44 %
#
#
# 2846
# Total Energy spent with an AI: 7531
# Total Energy spent with no AI: 13516
# ENERGY SAVED: 44 %
#
#
# 2847
# Total Energy spent with an AI: 7534
# Total Energy spent with no AI: 13516
# ENERGY SAVED: 44 %
#
#
# 2848
# Total Energy spent with an AI: 7598
# Total Energy spent with no AI: 13528
# ENERGY SAVED: 44 %
#
#
# 2849
# Total Energy spent with an AI: 7601
# Total Energy spent with no AI: 13528
# ENERGY SAVED: 44 %
#
#
# 2850
# Total Energy spent with an AI: 7604
# Total Energy spent with no AI: 13529
# ENERGY SAVED: 44 %
#
#
# 2851
# Total Energy spent with an AI: 7607
# Total Energy spent with no AI: 13532
# ENERGY SAVED: 44 %
#
#
# 2852
# Total Energy spent with an AI: 7610
# Total Energy spent with no AI: 13532
# ENERGY SAVED: 44 %
#
#
# 2853
# Total Energy spent with an AI: 7613
# Total Energy spent with no AI: 13532
# ENERGY SAVED: 44 %
#
#
# 2854
# Total Energy spent with an AI: 7616
# Total Energy spent with no AI: 13533
# ENERGY SAVED: 44 %
#
#
# 2855
# Total Energy spent with an AI: 7619
# Total Energy spent with no AI: 13546
# ENERGY SAVED: 44 %
#
#
# 2856
# Total Energy spent with an AI: 7622
# Total Energy spent with no AI: 13548
# ENERGY SAVED: 44 %
#
#
# 2857
# Total Energy spent with an AI: 7625
# Total Energy spent with no AI: 13557
# ENERGY SAVED: 44 %
#
#
# 2858
# Total Energy spent with an AI: 7628
# Total Energy spent with no AI: 13557
# ENERGY SAVED: 44 %
#
#
# 2859
# Total Energy spent with an AI: 7631
# Total Energy spent with no AI: 13566
# ENERGY SAVED: 44 %
#
#
# 2860
# Total Energy spent with an AI: 7634
# Total Energy spent with no AI: 13570
# ENERGY SAVED: 44 %
#
#
# 2861
# Total Energy spent with an AI: 7637
# Total Energy spent with no AI: 13570
# ENERGY SAVED: 44 %
#
#
# 2862
# Total Energy spent with an AI: 7640
# Total Energy spent with no AI: 13574
# ENERGY SAVED: 44 %
#
#
# 2863
# Total Energy spent with an AI: 7643
# Total Energy spent with no AI: 13582
# ENERGY SAVED: 44 %
#
#
# 2864
# Total Energy spent with an AI: 7646
# Total Energy spent with no AI: 13588
# ENERGY SAVED: 44 %
#
#
# 2865
# Total Energy spent with an AI: 7649
# Total Energy spent with no AI: 13588
# ENERGY SAVED: 44 %
#
#
# 2866
# Total Energy spent with an AI: 7652
# Total Energy spent with no AI: 13594
# ENERGY SAVED: 44 %
#
#
# 2867
# Total Energy spent with an AI: 7655
# Total Energy spent with no AI: 13604
# ENERGY SAVED: 44 %
#
#
# 2868
# Total Energy spent with an AI: 7658
# Total Energy spent with no AI: 13607
# ENERGY SAVED: 44 %
#
#
# 2869
# Total Energy spent with an AI: 7661
# Total Energy spent with no AI: 13608
# ENERGY SAVED: 44 %
#
#
# 2870
# Total Energy spent with an AI: 7664
# Total Energy spent with no AI: 13610
# ENERGY SAVED: 44 %
#
#
# 2871
# Total Energy spent with an AI: 7667
# Total Energy spent with no AI: 13613
# ENERGY SAVED: 44 %
#
#
# 2872
# Total Energy spent with an AI: 7670
# Total Energy spent with no AI: 13620
# ENERGY SAVED: 44 %
#
#
# 2873
# Total Energy spent with an AI: 7673
# Total Energy spent with no AI: 13626
# ENERGY SAVED: 44 %
#
#
# 2874
# Total Energy spent with an AI: 7676
# Total Energy spent with no AI: 13626
# ENERGY SAVED: 44 %
#
#
# 2875
# Total Energy spent with an AI: 7679
# Total Energy spent with no AI: 13638
# ENERGY SAVED: 44 %
#
#
# 2876
# Total Energy spent with an AI: 7682
# Total Energy spent with no AI: 13642
# ENERGY SAVED: 44 %
#
#
# 2877
# Total Energy spent with an AI: 7685
# Total Energy spent with no AI: 13650
# ENERGY SAVED: 44 %
#
#
# 2878
# Total Energy spent with an AI: 7688
# Total Energy spent with no AI: 13656
# ENERGY SAVED: 44 %
#
#
# 2879
# Total Energy spent with an AI: 7752
# Total Energy spent with no AI: 13667
# ENERGY SAVED: 43 %
#
#
# e_0.9_lr_5e-05_ep_150_es_False
# Savings: 0.43276565386796423

# %%
# Save the summary results of the entire grid search
df=pd.DataFrame(grid_search)
df['Results'] = results
df.to_csv('hyper_parameter_tuning_results.csv')
